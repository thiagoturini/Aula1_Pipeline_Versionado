# %% [markdown]
# ## 📋 O que você vai construir nesta aula
#
# Ao final desta aula, você terá criado um **pipeline completo de coleta de dados** que:
#
# 1. ✅ Conecta com uma API externa (TMDb)
# 2. ✅ Coleta dados de múltiplos filmes
# 3. ✅ Estrutura dados usando classes Python
# 4. ✅ Persiste dados em arquivos JSON
# 5. ✅ Versiona código com Git
# 6. ✅ Implementa tratamento de erros
# 7. ✅ Adiciona logging profissional
#
# **Resultado final**: Um sistema reutilizável para coleta e estruturação de dados de filmes.

# %% [markdown]
# ## Exercício 1: Setup e Request
#
# 1. Instale requests
# 2. Obtenha API key: https://www.themoviedb.org/settings/api
# 3. Crie `config.json`:
#    ```json
#    {"tmdb": {"api_key": "KEY", "base_url": "https://api.themoviedb.org/3", "language": "pt-BR"}}
#    ```
# 4. GET `/movie/550` - trate status 200/401/404
# 5. Crie `dados/` e salve `dados/filme_550.json`
# 6. Leia e exiba dados do arquivo
#
# Valida se: status 200, arquivo salvo, leitura funciona

# %%
# Implementação

# %% [markdown]
# ## Exercício 2: Coleta em Massa
#
# 1. GET `/movie/popular` - extraia 10 IDs do campo `results`
# 2. Função `buscar_filme_por_id(id)`: retorna dict ou None, delay 0.5s
# 3. Loop: colete 10 filmes, salve `dados/filme_{id}.json`, conte erros
# 4. Crie `dados/indice_filmes.json`: lista com id, title, release_date, vote_average ordenada por nota
#
# Valida: 10 arquivos criados, índice completo, erros tratados, rate limiting ativo

# %%
# Implementação

# %% [markdown]
# ## Exercício 3: Classes
#
# 1. `@dataclass Movie`:
#    - Obrigatórios: id, title, original_title, release_date, vote_average, vote_count
#    - Opcionais: budget=0, revenue=0, runtime=0, overview=""
#
# 2. `@staticmethod from_json(data: dict) -> Movie`: converte JSON API para Movie
#
# 3. Properties:
#    - `year -> int`: extrai ano de release_date (YYYY-MM-DD)
#    - `profit -> int`: revenue - budget
#    - `is_profitable -> bool`: profit > 0
#
# 4. `__post_init__`: valide id>0, 0<=vote_average<=10, runtime>=0, budget>=0, revenue>=0. Raise ValueError se inválido.
#
# Valida: instancia de JSON, properties corretas, validações funcionam, type hints presentes

# %%
# Implementação

# %% [markdown]
# ## Exercício 4: Git
#
# 1. `git init` + configure user.name e user.email
#
# 2. `.gitignore`: dados/, config.json, __pycache__/, *.pyc, venv/, *.log
#
# 3. Organize código:
#    - `tmdb_client.py`: load_config(), get_popular_movies(), get_movie_by_id()
#    - `models.py`: classe Movie
#    - `pipeline.py`: lógica principal
#
# 4. Commits:
#    ```bash
#    git add .gitignore && git commit -m "chore: adiciona .gitignore"
#    git add tmdb_client.py && git commit -m "feat: cliente TMDb"
#    git add models.py && git commit -m "feat: classe Movie"
#    git add pipeline.py && git commit -m "feat: pipeline coleta"
#    ```
#
# 5. Branch: `git checkout -b feature/error-handling`, adicione try/except, commit, merge em main
#
# Valida: repo inicializado, .gitignore funciona, 3 módulos, commits feat/fix/chore, branch mergeada

# %%
# Comandos Git (terminal)

# %% [markdown]
# ## Exercício 5: Logging e Pipeline
#
# 1. Configure logging: FileHandler + StreamHandler, formato `%(asctime)s - %(levelname)s - %(message)s`
#
# 2. `run_pipeline(num_movies=10)`:
#    - Load config → get popular → extract IDs → loop coleta → convert Movie → validate → save → índice → métricas
#    - Log início e fim com tempo decorrido
#
# 3. Métricas: total solicitado, sucesso, erro, tempo, nota média, mais popular (vote_count), mais lucrativo (profit)
#
# 4. `gerar_relatorio(filmes)`: salva JSON em `dados/relatorio.json` com timestamp, total, estatísticas
#
# Valida: logs em arquivo+console, pipeline end-to-end, métricas corretas, relatório gerado, aceita parâmetros

# %%
# Implementação

# %% [markdown]
# ## Checklist
#
# Infraestrutura:
# - [ ] Python 3.8+, requests, API key, config.json
#
# Código:
# - [ ] tmdb_client.py, models.py, pipeline.py
# - [ ] Type hints, docstrings
#
# Funcionalidades:
# - [ ] Coleta 10+ filmes, conversão Movie, validações
# - [ ] Error handling, rate limiting, logging
# - [ ] Índice e relatório gerados
#
# Git:
# - [ ] Repo inicializado, .gitignore, 5+ commits
# - [ ] Código modular, branch mergeada
#
# Qualidade:
# - [ ] PEP 8, nomes descritivos, funções únicas
# - [ ] Sem código comentado, sem print()

# %% [markdown]
# ## Extras (Opcional)
#
# N1: genres em Movie, filtro nota mínima, tqdm
# N2: cache local, busca por nome, CLI argparse
# N3: pytest, GitHub Actions, Docker
# N4: SQLite, FastAPI, Streamlit

# %% [markdown]
# ## Estrutura
#
# ```
# .git/, .gitignore, config.json, tmdb_client.py, models.py, pipeline.py
# dados/filme_*.json, indice_filmes.json, relatorio.json
# logs/pipeline_*.log
# ```

# %% [markdown]
# ## Referências
#
# TMDb API: https://developers.themoviedb.org/3
# Endpoints: /movie/popular, /movie/{id}
# Docs: requests, dataclasses, logging (Python stdlib)

# %% [markdown]
# ## Próximo
#
# Aula 2: SQL/schema/queries | Aula 3: FastAPI/REST | Aula 4: Streamlit/Docker/deploy

# %% [markdown]
# ## Stack Técnica
#
# - Python 3.8+
# - requests (HTTP client)
# - dataclasses (estruturação de dados)
# - json, pathlib (built-in)
# - logging (monitoramento)
# - Git (versionamento)
#
# ## API Utilizada
#
# TMDb API v3
# - Base URL: `https://api.themoviedb.org/3`
# - Requer cadastro gratuito para obter API key
# - Documentação: https://developers.themoviedb.org/3

# %% [markdown]
# ## Exercício 1: Setup e Primeira Requisição
#
# ### Tarefas
#
# 1. Configure o ambiente:
#    - Verifique Python 3.8+
#    - Instale `requests`
#    - Obtenha API key em https://www.themoviedb.org/settings/api
#
# 2. Crie arquivo `config.json`:
# ```json
# {
#   "tmdb": {
#     "api_key": "sua_chave_aqui",
#     "base_url": "https://api.themoviedb.org/3",
#     "language": "pt-BR"
#   }
# }
# ```
#
# 3. Faça requisição GET para `/movie/{movie_id}`:
#    - Teste com ID 550 (Fight Club)
#    - Trate status codes (200, 401, 404)
#    - Parse JSON response
#
# 4. Persista dados:
#    - Crie diretório `dados/`
#    - Salve response em `dados/filme_550.json`
#    - Implemente função de leitura
#
# ### Critérios de validação
#
# - Requisição retorna status 200
# - JSON é salvo corretamente
# - Consegue ler e exibir dados do arquivo

# %%
# Implementação Exercício 1

# %% [markdown]
# ## Exercício 2: Coleta Automatizada
#
# ### Tarefas
#
# 1. Liste filmes populares:
#    - Endpoint: `/movie/popular`
#    - Extraia IDs dos primeiros 10 filmes
#    - Parse campo `results` do JSON
#
# 2. Implemente função `buscar_filme_por_id(movie_id)`:
#    - Retorna dict com dados do filme
#    - Retorna None se erro
#    - Adiciona delay de 0.5s (rate limiting)
#
# 3. Loop de coleta:
#    - Itere pelos 10 IDs
#    - Salve cada filme em `dados/filme_{id}.json`
#    - Conte sucessos e falhas
#
# 4. Crie índice:
#    - Arquivo `dados/indice_filmes.json`
#    - Estrutura: lista de objetos com id, title, release_date, vote_average
#    - Ordene por vote_average (descendente)
#
# ### Critérios de validação
#
# - 10 arquivos JSON criados
# - Índice contém todos os filmes
# - Tratamento de erros implementado
# - Rate limiting funciona

# %%
# Implementação Exercício 2

# %% [markdown]
# ## Exercício 3: Estruturação com Classes
#
# ### Tarefas
#
# 1. Crie classe `Movie` usando `@dataclass`:
#
# Campos obrigatórios:
# - id: int
# - title: str
# - original_title: str
# - release_date: str
# - vote_average: float
# - vote_count: int
#
# Campos opcionais (com default):
# - budget: int = 0
# - revenue: int = 0
# - runtime: int = 0
# - overview: str = ""
#
# 2. Implemente método construtor:
# ```python
# @staticmethod
# def from_json(data: dict) -> 'Movie':
#     # Converte dict da API para objeto Movie
#     # Trata campos None e opcionais
#     pass
# ```
#
# 3. Adicione propriedades calculadas:
# ```python
# @property
# def year(self) -> int:
#     # Extrai ano de release_date (formato: YYYY-MM-DD)
#     pass
#
# @property
# def profit(self) -> int:
#     # Calcula revenue - budget
#     pass
#
# @property
# def is_profitable(self) -> bool:
#     # Retorna True se profit > 0
#     pass
# ```
#
# 4. Implemente validações em `__post_init__`:
# - id > 0
# - 0 <= vote_average <= 10
# - runtime >= 0
# - budget >= 0
# - revenue >= 0
#
# Levante `ValueError` com mensagem descritiva se inválido.
#
# ### Critérios de validação
#
# - Classe instancia corretamente de JSON da API
# - Propriedades calculam valores corretos
# - Validações impedem dados inválidos
# - Type hints em todos os métodos

# %%
# Implementação Exercício 3

# %% [markdown]
# ## Exercício 4: Versionamento com Git
#
# ### Tarefas
#
# 1. Inicialize repositório:
# ```bash
# git init
# git config user.name "Seu Nome"
# git config user.email "email@example.com"
# ```
#
# 2. Crie `.gitignore`:
# ```
# # Dados e configurações
# dados/
# config.json
#
# # Python
# __pycache__/
# *.pyc
# *.pyo
# .venv/
# venv/
#
# # Logs
# *.log
# ```
#
# 3. Organize código em módulos:
#
# `tmdb_client.py`:
# - Funções de requisição HTTP
# - load_config()
# - get_popular_movies()
# - get_movie_by_id()
#
# `models.py`:
# - Classe Movie completa
# - Validações e propriedades
#
# `pipeline.py`:
# - Lógica principal de coleta
# - Loop de processamento
# - Salvamento de arquivos
#
# 4. Commits estruturados:
# ```bash
# git add .gitignore
# git commit -m "chore: adiciona .gitignore"
#
# git add tmdb_client.py
# git commit -m "feat: adiciona cliente HTTP para TMDb API"
#
# git add models.py
# git commit -m "feat: adiciona classe Movie com validações"
#
# git add pipeline.py
# git commit -m "feat: implementa pipeline de coleta de dados"
# ```
#
# 5. Branch de feature:
# ```bash
# git checkout -b feature/error-handling
# # Adicione try/except robusto
# git add .
# git commit -m "feat: adiciona tratamento de erros HTTP"
# git checkout main
# git merge feature/error-handling
# ```
#
# ### Critérios de validação
#
# - Repositório inicializado
# - .gitignore impede commit de dados sensíveis
# - Código separado em 3 módulos
# - Mensagens de commit seguem convenção (feat/fix/chore)
# - Branch criada e mergeada com sucesso

# %%
# Referência de comandos Git
# Execute no terminal, não nesta célula

"""
# Status e histórico
git status
git log --oneline --graph

# Branches
git branch
git branch -a
git checkout -b nome-branch

# Merge
git checkout main
git merge nome-branch
git branch -d nome-branch
"""
# Out:
# '\n# Status e histórico\ngit status\ngit log --oneline --graph\n\n# Branches\ngit branch\ngit branch -a\ngit checkout -b nome-branch\n\n# Merge\ngit checkout main\ngit merge nome-branch\ngit branch -d nome-branch\n'

# %% [markdown]
# ## Exercício 5: Pipeline Completo com Logging
#
# ### Tarefas
#
# 1. Configure logging em `pipeline.py`:
# ```python
# import logging
# from datetime import datetime
#
# # Criar logger
# logger = logging.getLogger(__name__)
# logger.setLevel(logging.INFO)
#
# # Handler para arquivo
# fh = logging.FileHandler(f'pipeline_{datetime.now().strftime("%Y%m%d_%H%M%S")}.log')
# fh.setLevel(logging.INFO)
#
# # Handler para console
# ch = logging.StreamHandler()
# ch.setLevel(logging.INFO)
#
# # Formato
# formatter = logging.Formatter(
#     '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
# )
# fh.setFormatter(formatter)
# ch.setFormatter(formatter)
#
# logger.addHandler(fh)
# logger.addHandler(ch)
# ```
#
# 2. Implemente pipeline principal:
# ```python
# def run_pipeline(num_movies: int = 10):
#     logger.info("Iniciando pipeline de coleta")
#     start_time = datetime.now()
#
#     # 1. Carregar configuração
#     # 2. Buscar filmes populares
#     # 3. Extrair IDs
#     # 4. Loop de coleta
#     # 5. Converter para objetos Movie
#     # 6. Validar dados
#     # 7. Salvar arquivos
#     # 8. Gerar índice
#     # 9. Calcular métricas
#
#     end_time = datetime.now()
#     logger.info(f"Pipeline concluído em {end_time - start_time}")
# ```
#
# 3. Métricas a registrar:
# - Total de filmes solicitados
# - Total processado com sucesso
# - Total com erro
# - Tempo de execução
# - Média de nota dos filmes
# - Filme mais popular (maior vote_count)
# - Filme mais lucrativo
#
# 4. Gere relatório final:
# ```python
# def gerar_relatorio(filmes: list[Movie]):
#     report = {
#         "timestamp": datetime.now().isoformat(),
#         "total": len(filmes),
#         "estatisticas": {
#             "nota_media": ...,
#             "mais_popular": ...,
#             "mais_lucrativo": ...
#         }
#     }
#
#     with open("dados/relatorio.json", "w") as f:
#         json.dump(report, f, indent=2)
# ```
#
# ### Critérios de validação
#
# - Logs aparecem em arquivo e console
# - Pipeline executa end-to-end sem intervenção
# - Métricas calculadas corretamente
# - Relatório JSON gerado
# - Código aceita parâmetros (num_movies)

# %%
# Implementação Exercício 5

# %% [markdown]
# ## Checklist de Entrega
#
# ### Infraestrutura
# - [ ] Python 3.8+ configurado
# - [ ] requests instalado
# - [ ] API key do TMDb funcional
# - [ ] config.json criado (não commitado)
#
# ### Código
# - [ ] tmdb_client.py com funções HTTP
# - [ ] models.py com classe Movie
# - [ ] pipeline.py com lógica principal
# - [ ] Type hints em todas as funções
# - [ ] Docstrings nos módulos principais
#
# ### Funcionalidades
# - [ ] Coleta automática de 10+ filmes
# - [ ] Conversão para objetos Movie
# - [ ] Validação de dados
# - [ ] Tratamento de erros HTTP
# - [ ] Rate limiting implementado
# - [ ] Logging estruturado
# - [ ] Geração de índice
# - [ ] Geração de relatório
#
# ### Versionamento
# - [ ] Repositório Git inicializado
# - [ ] .gitignore configurado
# - [ ] Mínimo 5 commits descritivos
# - [ ] Código organizado em módulos
# - [ ] Branch criada e mergeada
#
# ### Qualidade
# - [ ] Código segue PEP 8
# - [ ] Nomes descritivos de variáveis
# - [ ] Funções com responsabilidade única
# - [ ] Sem código comentado
# - [ ] Sem print() (usar logging)

# %% [markdown]
# ## Desafios Adicionais (Opcional)
#
# Para quem quer ir além:
#
# ### Nível 1
# - Adicione campo `genres` à classe Movie (lista de gêneros)
# - Implemente filtro por nota mínima
# - Adicione progresso visual (tqdm)
#
# ### Nível 2
# - Implemente cache local (evita requisições duplicadas)
# - Adicione suporte a busca por nome do filme
# - Crie CLI com argparse (aceita argumentos via terminal)
#
# ### Nível 3
# - Implemente testes unitários (pytest)
# - Adicione CI/CD com GitHub Actions
# - Crie container Docker
#
# ### Nível 4
# - Adicione banco de dados SQLite
# - Implemente API REST com FastAPI
# - Dashboard com Streamlit

# %% [markdown]
# ## Estrutura de Diretórios Esperada
#
# ```
# Aula1_Pipeline_Versionado/
# ├── .git/
# ├── .gitignore
# ├── config.json              (não commitado)
# ├── tmdb_client.py
# ├── models.py
# ├── pipeline.py
# ├── README.md                (opcional)
# ├── requirements.txt         (opcional)
# ├── dados/
# │   ├── filme_*.json        (não commitados)
# │   ├── indice_filmes.json  (não commitado)
# │   └── relatorio.json      (não commitado)
# └── logs/
#     └── pipeline_*.log       (não commitados)
# ```

# %% [markdown]
# ## Recursos
#
# ### Documentação Oficial
# - TMDb API: https://developers.themoviedb.org/3
# - Python requests: https://requests.readthedocs.io/
# - Python dataclasses: https://docs.python.org/3/library/dataclasses.html
# - Python logging: https://docs.python.org/3/library/logging.html
# - Git: https://git-scm.com/doc
#
# ### Endpoints TMDb Úteis
# ```
# GET /movie/popular
# GET /movie/{movie_id}
# GET /search/movie?query={texto}
# GET /genre/movie/list
# ```
#
# ### Exemplo de Response da API
# ```json
# {
#   "id": 550,
#   "title": "Fight Club",
#   "release_date": "1999-10-15",
#   "vote_average": 8.4,
#   "budget": 63000000,
#   "revenue": 100853753,
#   "runtime": 139
# }
# ```

# %% [markdown]
# ## Próximas Aulas
#
# ### Aula 2 - SQL e Bancos de Dados
# Modelar schema relacional, inserir dados coletados, queries analíticas
#
# ### Aula 3 - APIs REST
# Criar API própria com FastAPI, endpoints CRUD, documentação automática
#
# ### Aula 4 - Integração e Deploy
# Dashboard Streamlit, containerização Docker, deploy na nuvem

# %% [markdown]
# ## 📋 O que você vai construir nesta aula
#
# Ao final desta aula, você terá criado um **pipeline completo de coleta de dados** que:
#
# 1. ✅ Conecta com uma API externa (TMDb)
# 2. ✅ Coleta dados de múltiplos filmes
# 3. ✅ Estrutura dados usando classes Python
# 4. ✅ Persiste dados em arquivos JSON
# 5. ✅ Versiona código com Git
# 6. ✅ Implementa tratamento de erros
# 7. ✅ Adiciona logging profissional
#
# **Resultado final**: Um sistema reutilizável para coleta e estruturação de dados de filmes.

# %% [markdown]
# ## 🚀 Parte 1: Setup e Primeira Requisição
#
# ### Objetivos
# - Configurar ambiente Python
# - Obter e configurar API key do TMDb
# - Fazer sua primeira requisição HTTP
# - Entender resposta JSON
#
# ### Desafios
#
# **Desafio 1.1**: Configure seu ambiente
# - Verifique a versão do Python (3.8+)
# - Instale a biblioteca `requests`
# - Crie o arquivo `config.json` com sua API key
#
# **Desafio 1.2**: Faça sua primeira requisição
# - Busque informações do filme ID 550 (Clube da Luta)
# - Imprima o título e a nota do filme
# - Identifique 5 campos interessantes no JSON de resposta
#
# **Desafio 1.3**: Persistência
# - Crie uma pasta `dados/`
# - Salve o JSON do filme em `dados/filme_550.json`
# - Leia o arquivo e mostre o título
#
# ### Perguntas para refletir
# 1. O que é uma API REST?
# 2. O que significa status code 200? E 404?
# 3. Por que usar JSON para armazenar dados?
# 4. Como proteger sua API key?

# %%
# Espaço para seus testes - Parte 1
# Configure seu ambiente e faça a primeira requisição aqui

# %% [markdown]
# ## 📦 Parte 2: Coleta em Massa
#
# ### Objetivos
# - Buscar lista de filmes populares
# - Iterar e coletar múltiplos filmes
# - Implementar tratamento de erros
# - Criar índice de dados coletados
#
# ### Desafios
#
# **Desafio 2.1**: Liste filmes populares
# - Use o endpoint `/movie/popular`
# - Extraia os IDs dos 10 primeiros filmes
# - Mostre título e nota de cada um
#
# **Desafio 2.2**: Coleta automatizada
# - Crie uma função `buscar_filme_por_id(id)`
# - Use um loop para coletar os 10 filmes
# - Salve cada filme em `dados/filme_{id}.json`
# - Adicione um delay de 0.5s entre requisições (rate limiting)
#
# **Desafio 2.3**: Tratamento de erros
# - O que acontece se o ID não existir?
# - Implemente try/except para capturar erros
# - Teste com um ID inválido (999999999)
#
# **Desafio 2.4**: Índice
# - Crie um arquivo `dados/indice_filmes.json`
# - Liste todos os filmes coletados com:
#   - ID, título, ano, nota
#
# ### Perguntas para refletir
# 1. Por que é importante tratar erros HTTP?
# 2. O que é rate limiting e por que usamos delay?
# 3. Como você organizaria 1000 filmes?
# 4. Qual a diferença entre dados brutos e dados processados?

# %%
# Espaço para seus testes - Parte 2
# Implemente a coleta automatizada aqui

# %% [markdown]
# ## 🏗️ Parte 3: Estruturação com Classes
#
# ### Objetivos
# - Transformar dicionários em objetos Python
# - Usar dataclasses para modelagem
# - Implementar validações
# - Adicionar propriedades calculadas
#
# ### Desafios
#
# **Desafio 3.1**: Crie a classe Movie
# - Use `@dataclass` do Python
# - Campos: id, title, release_date, vote_average, budget, revenue, runtime
# - Implemente `__post_init__` para validações
#
# **Desafio 3.2**: Método construtor
# - Crie `@staticmethod def from_json(data)`
# - Converta JSON da API para objeto Movie
# - Trate campos opcionais/nulos
#
# **Desafio 3.3**: Propriedades calculadas
# - `@property def year`: extrair ano de release_date
# - `@property def profit`: calcular revenue - budget
# - `@property def is_profitable`: retornar boolean
#
# **Desafio 3.4**: Validações
# - ID deve ser positivo
# - Nota entre 0 e 10
# - Duração maior que 0
# - Budget e revenue não negativos
#
# ### Perguntas para refletir
# 1. Qual a vantagem de usar classes vs dicionários?
# 2. O que são dataclasses e por que usá-las?
# 3. Quando usar @property vs método normal?
# 4. Como validações previnem bugs?

# %%
# Espaço para seus testes - Parte 3
# Crie sua classe Movie aqui

# %% [markdown]
# ## 📝 Parte 4: Versionamento com Git
#
# ### Objetivos
# - Inicializar repositório Git
# - Criar commits significativos
# - Trabalhar com branches
# - Entender .gitignore
#
# ### Desafios
#
# **Desafio 4.1**: Inicialize o repositório
# ```bash
# git init
# git config user.name "Seu Nome"
# git config user.email "seu@email.com"
# ```
#
# **Desafio 4.2**: Primeiro commit
# - Crie `.gitignore` (ignorar `dados/`, `config.json`, `__pycache__/`)
# - Adicione seus scripts Python
# - Commit: "feat: adiciona coleta de dados TMDb"
#
# **Desafio 4.3**: Organize em arquivos
# - `tmdb_client.py`: funções de requisição
# - `models.py`: classe Movie
# - `main.py`: pipeline principal
# - Commit cada arquivo separadamente
#
# **Desafio 4.4**: Branch de feature
# - Crie branch `feature/validacoes`
# - Adicione validações à classe Movie
# - Merge de volta para main
#
# ### Perguntas para refletir
# 1. Por que versionamento é importante?
# 2. O que não deve ser versionado?
# 3. Como escrever boas mensagens de commit?
# 4. Quando criar uma branch?

# %%
# Comandos Git - execute no terminal
# Este é apenas um guia de referência

"""
# Inicializar
git init

# Adicionar arquivos
git add models.py
git commit -m "feat: adiciona classe Movie"

# Ver status
git status
git log --oneline

# Branches
git branch feature/validacoes
git checkout feature/validacoes
# ... fazer mudanças ...
git checkout main
git merge feature/validacoes
"""
# Out:
# '\n# Inicializar\ngit init\n\n# Adicionar arquivos\ngit add models.py\ngit commit -m "feat: adiciona classe Movie"\n\n# Ver status\ngit status\ngit log --oneline\n\n# Branches\ngit branch feature/validacoes\ngit checkout feature/validacoes\n# ... fazer mudanças ...\ngit checkout main\ngit merge feature/validacoes\n'

# %% [markdown]
# ## 📊 Parte 5: Pipeline Completo com Logging
#
# ### Objetivos
# - Implementar logging estruturado
# - Integrar todas as partes
# - Criar pipeline end-to-end
# - Adicionar métricas de execução
#
# ### Desafios
#
# **Desafio 5.1**: Configure logging
# ```python
# import logging
#
# logging.basicConfig(
#     level=logging.INFO,
#     format='%(asctime)s - %(levelname)s - %(message)s',
#     handlers=[
#         logging.FileHandler('pipeline.log'),
#         logging.StreamHandler()
#     ]
# )
# ```
#
# **Desafio 5.2**: Pipeline principal
# Crie um script que:
# 1. Carrega configuração
# 2. Busca filmes populares
# 3. Coleta detalhes de cada filme
# 4. Converte para objetos Movie
# 5. Salva dados estruturados
# 6. Gera relatório final
#
# **Desafio 5.3**: Métricas
# - Total de filmes processados
# - Tempo de execução
# - Sucesso vs erros
# - Estatísticas (média de notas, etc.)
#
# **Desafio 5.4**: Torne reutilizável
# - Aceite parâmetros (quantos filmes coletar)
# - Permita diferentes endpoints
# - Adicione opções de configuração
#
# ### Perguntas para refletir
# 1. Por que logging é melhor que print()?
# 2. Quais níveis de log usar quando?
# 3. Como monitorar um pipeline em produção?
# 4. O que torna código "production-ready"?

# %%
# Espaço para seu pipeline completo
# Integre tudo aqui

# %% [markdown]
# ## 🎯 Checklist de Conclusão
#
# Marque conforme você completa cada item:
#
# ### Setup Básico
# - [ ] Python 3.8+ instalado e funcionando
# - [ ] requests instalado
# - [ ] API key do TMDb obtida e configurada
# - [ ] config.json criado
#
# ### Coleta de Dados
# - [ ] Requisição simples funcionando
# - [ ] Coleta de 10+ filmes implementada
# - [ ] Tratamento de erros HTTP
# - [ ] Dados salvos em JSON
# - [ ] Índice de filmes criado
#
# ### Estruturação
# - [ ] Classe Movie implementada com dataclass
# - [ ] Método from_json funcionando
# - [ ] Propriedades calculadas (year, profit, etc.)
# - [ ] Validações implementadas
# - [ ] Testes com dados reais
#
# ### Versionamento
# - [ ] Repositório Git inicializado
# - [ ] .gitignore configurado
# - [ ] Commits organizados e descritivos
# - [ ] Código separado em módulos
# - [ ] Branch criada e mergeada
#
# ### Pipeline Completo
# - [ ] Logging configurado
# - [ ] Pipeline end-to-end funcionando
# - [ ] Métricas implementadas
# - [ ] Código reutilizável
# - [ ] Documentação básica
#
# ### Bônus (Desafios Extra)
# - [ ] Type hints em todas as funções
# - [ ] Docstrings em classes e métodos
# - [ ] Testes unitários básicos
# - [ ] CLI com argparse
# - [ ] README.md completo

# %% [markdown]
# ## 💡 Dicas para Alunos Avançados
#
# ### Se você já tem experiência
# 1. **Pule o básico**: Vá direto para os desafios que te interessam
# 2. **Adicione complexidade**: Implemente os desafios bônus
# 3. **Explore mais**:
#    - Adicione mais campos à classe Movie
#    - Colete dados de séries (TV shows)
#    - Implemente cache de requisições
#    - Crie testes automatizados
#
# ### Se você está aprendendo
# 1. **Vá devagar**: Faça um desafio por vez
# 2. **Use os notebooks numerados**: Eles têm explicações detalhadas
# 3. **Experimente**: Mude valores, quebre o código, aprenda com erros
# 4. **Pergunte**: As perguntas de reflexão são importantes
#
# ### Recursos Adicionais
# - **TMDb API Docs**: https://developers.themoviedb.org/3
# - **Python Requests**: https://requests.readthedocs.io/
# - **Dataclasses**: https://docs.python.org/3/library/dataclasses.html
# - **Git Basics**: https://git-scm.com/book/en/v2

# %% [markdown]
# ## 🏆 Próximos Passos
#
# Após completar esta aula, você estará pronto para:
#
# ### Aula 2 - SQL e Bancos de Dados
# - Modelar dados relacionais
# - Criar schemas SQL
# - Inserir dados coletados
# - Fazer queries analíticas
#
# ### Aula 3 - APIs REST
# - Criar sua própria API
# - Servir dados via HTTP
# - Implementar endpoints RESTful
# - Documentação com Swagger
#
# ### Aula 4 - Integração e Deploy
# - Dashboard interativo
# - Deploy em Docker
# - Automação com CI/CD
# - Monitoramento em produção
#
# ---
#
# **Boa sorte! 🚀**
#
# Lembre-se: o importante não é só fazer funcionar, mas **entender como e por que funciona**.
